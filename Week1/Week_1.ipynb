# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget -O /content/drive/MyDrive/Vanh_GR1/KDDTrain+.txt  "https://raw.githubusercontent.com/jmnwong/NSL-KDD-Dataset/master/KDDTrain+.txt"
# !wget -O /content/drive/MyDrive/Vanh_GR1/KDDTest+.txt  "https://raw.githubusercontent.com/jmnwong/NSL-KDD-Dataset/master/KDDTest+.txt"
# Out:
# --2026-03-18 16:01:42--  https://raw.githubusercontent.com/jmnwong/NSL-KDD-Dataset/master/KDDTrain+.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19109424 (18M) [text/plain]
# Saving to: ‘/content/drive/MyDrive/Vanh_GR1/KDDTrain+.txt’
#
# /content/drive/MyDr 100%[===================>]  18.22M  63.4MB/s    in 0.3s
#
# 2026-03-18 16:01:43 (63.4 MB/s) - ‘/content/drive/MyDrive/Vanh_GR1/KDDTrain+.txt’ saved [19109424/19109424]
#
# --2026-03-18 16:01:43--  https://raw.githubusercontent.com/jmnwong/NSL-KDD-Dataset/master/KDDTest+.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
import torch
TORCH = torch.__version__.split('+')[0]
CUDA  = 'cu121' if torch.cuda.is_available() else 'cpu'

# !pip install torch_geometric -q
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv \
    -f https://data.pyg.org/whl/torch-{TORCH}+{CUDA}.html -q

# %%
# !python /content/drive/MyDrive/Vanh_GR1/build_graph_nslkdd.py
# Out:
# Dang doc NSL-KDD...
#   Tong so dong: 148517
# Dang gop nhan...
#   Phan bo nhan:
#     NORMAL    :   77054
#     DoS       :   53385
#     Probe     :   14077
#     R2L       :    3749
#     U2R       :     252
# Dang ma hoa...
#   Nhan: [(0, 'DoS'), (1, 'NORMAL'), (2, 'Probe'), (3, 'R2L'), (4, 'U2R')]
# Dang tao node...
#   So node: 72
# Dang tao canh...
#   So canh: 148517
# Dang tao features...
#   Node feature shape: torch.Size([72, 41])
# Dang gan nhan node...
#   Node binh thuong: 55
#   Node bi tan cong: 17
#   Train/Val/Test: 43/14/15
#
# Do thi NSL-KDD tao xong!
#   So node: 72
#   So canh: 148517
#   Feature dim: 41
#
# Da luu tai: /content/drive/MyDrive/gnn_models/nslkdd_graph.pt

# %%
# Sửa trực tiếp trên Colab
# !sed -i "s/map_location=device)/map_location=device, weights_only=False)/" /content/drive/MyDrive/Vanh_GR1/gat_nslkdd.py
# !python /content/drive/MyDrive/Vanh_GR1/gat_nslkdd.py
# Out:
# Dung device: cuda
# Dang load do thi NSL-KDD...
#   So node:     72
#   So canh:     148517
#   Feature dim: 41
#   So nhan:     5 → ['DoS', 'NORMAL', 'Probe', 'R2L', 'U2R']
#
# Epoch: 001, Loss: 4.6738, Train: 0.0233, Val: 0.0000, Test: 000
# Epoch: 002, Loss: 3.3295, Train: 0.1395, Val: 0.0714, Test: 0.0667
# Epoch: 003, Loss: 3.9751, Train: 0.6047, Val: 0.5714, Test: 0.7333
# Epoch: 004, Loss: 1.9978, Train: 0.6279, Val: 0.6429, Test: 0.8000
# Epoch: 005, Loss: 3.8576, Train: 0.6512, Val: 0.7143, Test: 0.8000
# Epoch: 006, Loss: 2.5770, Train: 0.6512, Val: 0.7143, Test: 0.8000
# Epoch: 007, Loss: 5.8200, Train: 0.6977, Val: 0.7857, Test: 0.8000
# Epoch: 008, Loss: 1.7176, Train: 0.7907, Val: 0.7857, Test: 0.8000
# Epoch: 009, Loss: 2.5389, Train: 0.7907, Val: 0.7857, Test: 0.8000
# Epoch: 010, Loss: 2.0463, Train: 0.7907, Val: 0.7857, Test: 0.8000
# Epoch: 011, Loss: 1.6393, Train: 0.7907, Val: 0.7857, Test: 0.8000
# ...

# %%
# !python /content/drive/MyDrive/Vanh_GR1/predict_nslkdd.py
# Out:
# Dang load do thi...
# Dang load model...
# Load xong!
#   Best Val Acc luc train: 0.7857
#   Test Acc luc train:     0.8000
#   Cac nhan: ['DoS', 'NORMAL', 'Probe', 'R2L', 'U2R']
#
# ...
#   Node | Du doan         | Thuc te         | OK?
# ...
#      6 | DoS             | DoS             | OK
#      7 | DoS             | Probe           | SAI
#     10 | DoS             | DoS             | OK
#     17 | DoS             | DoS             | OK
#     18 | DoS             | DoS             | OK
#     20 | DoS             | R2L             | SAI
#     22 | DoS             | DoS             | OK
#     24 | DoS             | DoS             | OK
#     28 | DoS             | DoS             | OK
#     30 | DoS             | DoS             | OK
#     31 | DoS             | DoS             | OK
#     35 | DoS             | DoS             | OK
#     43 | DoS             | DoS             | OK
#     50 | DoS             | DoS             | OK
#     60 | DoS             | DoS             | OK
# ...

# %%
# !python /content/drive/MyDrive/Vanh_GR1/gcn_nslkdd.py
# Out:
# Dung device: cuda
# Dang load do thi NSL-KDD...
#   So node:     72
#   So canh:     148517
#   Feature dim: 41
#   So nhan:     5 → ['DoS', 'NORMAL', 'Probe', 'R2L', 'U2R']
#
# Epoch: 001, Loss: 10.1373, Train: 0.1628, Val: 0.0714, Test: 0.0000
# Epoch: 002, Loss: 11.9885, Train: 0.1163, Val: 0.0714, Test: 0.0000
# Epoch: 003, Loss: 3.6648, Train: 0.0465, Val: 0.1429, Test: 0.0000
# Epoch: 004, Loss: 6.9885, Train: 0.0930, Val: 0.1429, Test: 0.0000
# Epoch: 005, Loss: 7.0674, Train: 0.3488, Val: 0.3571, Test: 0.4000
# Epoch: 006, Loss: 1.5966, Train: 0.5349, Val: 0.7143, Test: 0.6000
# Epoch: 007, Loss: 5.1419, Train: 0.6279, Val: 0.7857, Test: 0.8667
# Epoch: 008, Loss: 1.7238, Train: 0.6977, Val: 0.7857, Test: 0.8667
# Epoch: 009, Loss: 2.4706, Train: 0.6977, Val: 0.7857, Test: 0.8667
# Epoch: 010, Loss: 1.6821, Train: 0.6977, Val: 0.7857, Test: 0.8667
# Epoch: 011, Loss: 1.4695, Train: 0.6977, Val: 0.7857, Test: 0.8667
# ...

# %%
# !python /content/drive/MyDrive/Vanh_GR1/predict_nslkdd_all.py
# Out:
#    Số node: 72 | Số nhãn: 5
#
#    Val Acc: 0.7857 | Test Acc: 0.8667
#    Val Acc: 0.7857 | Test Acc: 0.8000
#
# ...
#   Node |         GCN          |         GAT          |     Thực tế     | Đồng ý?
# ...
#      6 |         DoS✅         |         DoS✅         |       DoS
#      7 |         DoS❌         |         DoS❌         |      Probe
#     10 |         DoS✅         |         DoS✅         |       DoS
#     17 |         DoS✅         |         DoS✅         |       DoS
#     18 |         DoS✅         |         DoS✅         |       DoS
#     20 |         DoS❌         |         DoS❌         |       R2L
#     22 |         DoS✅         |         DoS✅         |       DoS
#     24 |         DoS✅         |         DoS✅         |       DoS
#     28 |         DoS✅         |         DoS✅         |       DoS
#     30 |         DoS✅         |         DoS✅         |       DoS
#     31 |         DoS✅         |         DoS✅         |       DoS
# ...
